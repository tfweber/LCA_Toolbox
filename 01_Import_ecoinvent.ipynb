# %% [markdown]
# This part of the repository is for importing ecoinvent, given that you have downloaded Ecospold2 files from the ecoinvent website. If that is the case, you must make sure you installed Brightway 2.5 and have an active environment to work in.

# %% [markdown]
# # EcoInvent import

# %% [markdown]
# ### 1. Install required packages
#
# Before starting here with your work in brightway, make sure that you followed the steps in the README.md section to install brightway on your machine and setup an environment to work in.

# %%
# basic imports from brightway
import bw2analyzer as ba
import bw2calc as bc
import bw2data as bd
import bw2io as bi
from bw2io.importers import SingleOutputEcospold2Importer
import bw2analyzer as bwa
from bw2data import methods
from bw2io import create_default_biosphere3

# other relevant packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
# Out:
# 15:06:40+0200 [warning  ] Can't import `SimaProBlockCSVImporter` - please install `bw2io` with `pip install bw2io[multifunctional]` or install `multifunctional` and `bw_simapro_csv` manually.

# %% [markdown]
# ### 2. Setup the project

# %%
# Define a project name that you want to work in
bd.projects.set_current('LCA_Toolbox')

# %%
# When checking the databases for the first time you shouldn't see any databases
bd.databases
# Out:
# Databases dictionary with 3 object(s):
# 	BONSAI_V2.1.6
# 	BONSAI_V2.1.6 biosphere
# 	ecoinvent-3.10-biosphere

# %% [markdown]
# ### 3. Use BW ecoinvent installer

# %% [markdown]
# Note that there are different ways of importing ecoinvent to your brightway project. If you have username and password at hand you can install the database just using this access codes. The first suggestion is to use a structured importer available from the brightway cloud.

# %%
bi.import_ecoinvent_release(
    version='3.12',
    system_model='consequential', # can be cutoff / apos / consequential / EN15804
    username='username',
    password='password'
    )
# Out:
# Applying strategy: normalize_units
# Applying strategy: drop_unspecified_subcategories
# Applying strategy: ensure_categories_are_tuples
# Applied 3 strategies in 0.02 seconds
# Graph statistics for `ecoinvent-3.12-biosphere` importer:
# 9850 graph nodes:
# 	emission: 9477
# 	natural resource: 353
# 	inventory indicator: 15
# 	economic: 5
# 0 graph edges:
# 0 edges to the following databases:
# 0 unique unlinked edges (0 total):
# 100%|██████████| 9850/9850 [00:00<00:00, 12279.12it/s]
# 15:06:46+0200 [info     ] Vacuuming database
# Created database: ecoinvent-3.12-biosphere
# Extracting XML data from 23191 datasets
# 15:13:49+0200 [info     ] Extracted 23191 datasets in 411.75 seconds
# Applying strategy: normalize_units
# Applying strategy: update_ecoinvent_locations
# Applying strategy: remove_zero_amount_coproducts
# Applying strategy: remove_zero_amount_inputs_with_no_activity
# Applying strategy: remove_unnamed_parameters
# Applying strategy: es2_assign_only_product_with_amount_as_reference_product
# Applying strategy: assign_single_product_as_activity
# Applying strategy: create_composite_code
# Applying strategy: drop_unspecified_subcategories
# Applying strategy: fix_ecoinvent_flows_pre35
# Applying strategy: drop_temporary_outdated_biosphere_flows
# Applying strategy: link_biosphere_by_flow_uuid
# Applying strategy: link_internal_technosphere_by_composite_code
# Applying strategy: delete_exchanges_missing_activity
# Applying strategy: delete_ghost_exchanges
# Applying strategy: remove_uncertainty_from_negative_loss_exchanges
# Applying strategy: fix_unreasonably_high_lognormal_uncertainties
# Applying strategy: convert_activity_parameters_to_list
# Applying strategy: add_cpc_classification_from_single_reference_product
# Applying strategy: delete_none_synonyms
# Applying strategy: update_social_flows_in_older_consequential
# Applying strategy: set_lognormal_loc_value
# Applied 22 strategies in 23.56 seconds
# Graph statistics for `ecoinvent-3.12-consequential` importer:
# 23191 graph nodes:
# 	process: 23191
# 726722 graph edges:
# 	biosphere: 434383
# 	technosphere: 269148
# 	production: 23191
# 726722 edges to the following databases:
# 	ecoinvent-3.12-biosphere: 434383
# 	ecoinvent-3.12-consequential: 292339
# 0 unique unlinked edges (0 total):
#
#
# 15:14:17+0200 [warning  ] Not able to determine geocollections for all datasets. This database is not ready for regionalization.
# 100%|██████████| 23191/23191 [03:37<00:00, 106.64it/s]
# 15:17:56+0200 [info     ] Vacuuming database
# Created database: ecoinvent-3.12-consequential

# %% [markdown]
# ### 4. Install manually with Ecospold files

# %%
# download the ecoinvent biosphere3 database
create_default_biosphere3()

# %%
# import the biosphere 3.10 database from ecoinvent
bi.remote.install_project('ecoinvent-3.12-biosphere','LCA_Toolbox',
                                  overwrite_existing=True)

# %%
# You are required to specify the path to your ecoinvent files here
ei_path = "C:\\Users\\TimWeber\\OneDrive - 2.-0 LCA Consultants ApS\\Desktop\\ecoinvent_310\\background\\ecoinvent 3.10_consequential_ecoSpold02\\datasets"
ei_conseq = "ecoinvent310clca"

# %%
ei_importer = SingleOutputEcospold2Importer(ei_path, ei_conseq)

# %%
ei_importer.apply_strategies()

# %%
ei_importer.write_database()

# %%
pd.DataFrame(ei_importer.unlinked)

# %% [markdown]
# ### 5. Handle databases

# %%
# show databases
bd.databases
# Out:
# Databases dictionary with 5 object(s):
# 	BONSAI_V2.1.6
# 	BONSAI_V2.1.6 biosphere
# 	ecoinvent-3.10-biosphere
# 	ecoinvent-3.12-biosphere
# 	ecoinvent-3.12-consequential

# %%
del bd.databases["ecoinvent-3.10-biosphere"]

# %%
del bd.databases["ecoinvent-3.11-biosphere"]

# %%
del bd.databases["ecoinvent-3.11-consequential"]
